# %% [markdown]
# # while Loop

# %%
num = 2
while num > 0:
    print("Ali")
    num -=1
    print(num)
# Out:
# Ali
# 1
# Ali
# 0

# %%
clean_cities = ["islamabad", "karachi"]

# %%
user_city = input("Enter your city: ")
for city in clean_cities:
    if user_city == city:
        print(f"{user_city} is a clean city. ")
# Out:
# Enter your city:  karachi
# karachi is a clean city.

# %%
user_input = ""
while user_input != "quit":
    user_input = input("Enter a city to check or quit to stop the code: ")

    if user_input != "quit":
        for city in clean_cities:
            if user_input == city:
                print(f"{user_city} is a clean city. ")
# Out:
# Enter a city to check or quit to stop the code:  karachi
# karachi is a clean city.
# Enter a city to check or quit to stop the code:  islamabad
# karachi is a clean city.
# Enter a city to check or quit to stop the code:  quit

# %% [markdown]
# # Task:
#
# * create a number guessing game, where you will have a secret number and your will use a while to take an input from user and match the number , if the number mates so display a congratulation massage other wise ask the number again.

# %%
secret_number = 48 
num = 0
while num != secret_number:
    num = int(input("Enter your guess: "))
    
    if num == secret_number:
        print("Congratulations! You guessed the correct number!")
    else:
        print(" Wrong guess, try again!")
# Out:
# Enter your guess:  4
#  Wrong guess, try again!
# Enter your guess:  48
# Congratulations! You guessed the correct number!

# %%
secrat_number = 56
num = 0
while num != secrat_number:
    num = int(input("Enter your secrat_number: "))
    if num == secrat_number:
        print("Congratulation! your secrat_number is correct!")
    else:
        print("wrong secrat_number. please try again")
# Out:
# Enter your secrat_number:  5
# wrong secrat_number. please try again
# Enter your secrat_number:  46
# wrong secrat_number. please try again
# Enter your secrat_number:  56
# Congratulation! your secrat_number is correct!

# %%
secret_number = 34
attempts = 5

while attempts > 0:
    guess = int(input("Guess the number: "))
    
    if guess == secret_number:
        print("Congratulations! You guessed it right!")
        break
    else:
        attempts -= 1
        print("Wrong guess! Attempts left:", attempts)

if attempts == 0:
    print("Game Over! The secret number was", secret_number)
# Out:
# Guess the number:  3
# Wrong guess! Attempts left: 4
# Guess the number:  4
# Wrong guess! Attempts left: 3
# Guess the number:  34
# Congratulations! You guessed it right!

# %%
secret_number = 45
attempts = 5

while attempts > 0:
    guess = int(input("Guess the number: "))
    
    if guess == secret_number:
        print("Congratulations! Your secret number is correct!")
        break
    else:
        attempts -= 1
        print("Wrong! Attempts left:", attempts)

if attempts == 0:
    print("Game Over! The secret number was", secret_number)
# Out:
# Guess the number:  34
# Wrong! Attempts left: 4
# Guess the number:  56
# Wrong! Attempts left: 3
# Guess the number:  45
# Congratulations! Your secret number is correct!

# %% [markdown]
# # Classes

# %%
secrate_number = 44
attempts = 5
while attempts > 0:
    select = int(input("select the number: "))
    if select == secrate_number:
        print("Congratulation your number is correct")
        break
    else:
        attempts -= 1
        print("wrong numbr")
    if attempts == 0:
        print("gamer is over secrate number",secrate_number)
# Out:
# select the number:  54
# wrong numbr
# select the number:  44
# Congratulation your number is correct
