# %% [markdown]
# # Function

# %%
bio_data = {
    "first_name": "Qayas",
    "last_name":  "Abbasi"
}

# %%
bio_data
# Out:
# {'first_name': 'Qayas', 'last_name': 'Abbasi'}

# %%
num1 =30
num2 = 35
total = num1 + num2
print(total)
# Out:
# 65

# %% [markdown]
# # function is a block of code which perform specific a task.

# %%
def add_nums():
    num1 =30
    num2 = 35
    total = num1 + num2
    print(total)

# %%
add_nums()
# Out:
# 65

# %% [markdown]
# # Passing information to function

# %%
def add_nums(num1, num2, num3):   #-----> parameter
    total = num1 + num2 + num3
    print(total)

# %%
add_nums(20,30,50)  #-----> Arguments
# Out:
# 100

# %%
type(num1)
# Out:
# int

# %%
def add_nums(num1, num2):   #-----> parameter
    total = num1 + num2 
    print(total)

# %%
add_nums(25,40)
# Out:
# 65

# %%
def bio_data(last_name,first_name,age,weight):
    print(last_name)
    print(first_name)
    print(age)
    print(weight)

# %%
bio_data("Abbasi", "Qayas", 35, 54)
# Out:
# Abbasi
# Qayas
# 35
# 54

# %%
def bio_data(last_name,first_name,weight,age):
    print(last_name)
    print(first_name)
    print(age)
    print(weight)

# %%
first_name=input("enter your first_name:")
last_name=input("enter your last_name:")
weight=float(input("enter your weight"))
age=int(input("enter your age"))
# Out:
# enter your first_name: Qayas
# enter your last_name: abbasi
# enter your weight 54
# enter your age 35

# %%
bio_data(first_name= first_name , last_name= last_name, age= age,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 bio_data(first_name= first_name , last_name= last_name, age= age,)
#
# TypeError: bio_data() got an unexpected keyword argument 'first_name'

# %%
def bio_data_with_default(last_name,first_name,weight=65,age): #parameter without a default follows parameter with a default
    print(last_name)
    print(first_name)
    print(age)
    print(weight)
# Out:
#   Cell In[30], line 1
#     def bio_data_with_default(last_name,first_name,weight=65,age): #parameter without a default follows parameter with a default
#                                                              ^
# SyntaxError: parameter without a default follows parameter with a default

# %%
def bio_data_with_default(last_name,first_name,age,weight=65):
    print(last_name)
    print(first_name)
    print(age)
    print(weight)

# %%
bio_data_with_default(first_name=first_name , last_name=last_name, age=age,)
# Out:
# abbasi
# Qayas
# 35
# 65

# %%
bio_data_with_default(first_name=first_name , last_name=last_name, age=age,weight=55)
# Out:
# abbasi
# Qayas
# 35
# 55

# %%
def bio_data():
    first_name = input("Enter your first_name: ")
    last_name = input("Enter your last_name: ")
    age = input("Enter your age: ")
    weight = input("Enter your weight: ")
    
    print("!-------Bio_Data----!")
    print("first_name", first_name)
    print("last_name", last_name)
    print("age", age)
    print("weight", weight)

# %%
bio_data()
# Out:
# Enter your first_name:  Qayas
# Enter your last_name:  Abbasi
# Enter your age:  35
# Enter your weight:  50
# !-------Bio_Data----!
# first_name Qayas
# last_name Abbasi
# age 35
# weight 50

# %% [markdown]
# # Task:
#
# * write a function call registration which take email,name  and pasword from user and save in them in dict of dict ,for the first dict the key should be user's email and value should be a dick where you will store user's name and password.
# * write another funtion which take email an password and check in te saved date, if email match the key so his password and print a login message with his name.

# %%
user_info= {}

# %%
def registration(name,email,password):
    user_info[email] = {"name": name, "password": password}

# %%
registration("Qayas", "qayasabbasigmail.com", 1234)

# %%
user_info
# Out:
# {'qayasabbasigmail.com': {'name': 'Qayas', 'password': 1234}}

# %%
registration("Anas", "anaskhan@gmail.com", 45678)

# %%
user_info
# Out:
# {'qayasabbasigmail.com': {'name': 'Qayas', 'password': 1234},
#  'anaskhan@gmail.com': {'name': 'Anas', 'password': 45678}}

# %%
def login(email, password):
    if email in user_info.keys():
        if password == user_info[email]["password"]:
            print(f"{user_info[email]['name']}, Login successfully.")
        else:
            print("Wrong password.")
    else:
        print("Email not found.")

# %%
login("qayasabbasigmail.com", 1234)
login("qayasabbasigmail.com", 1214)
login("aayasabbasigmail.com", 1234)
# Out:
# Qayas, Login successfully.
# Wrong password.
# Email not found.

# %%
num1 = 30
num2 = 35
total  =  num1 + num2
print(total)
# Out:
# 65

# %% [markdown]
# # function is a block of code which perform a specific task

# %%
def add_nums():
    num1 = 30
    num2 = 35
    total  =  num1 + num2
    print(total)

# %%
add_nums()
# Out:
# 65

# %%
token = add_nums

# %%
def add_nums():
    num1 = 30
    num2 = 45
    total = num1 + num2
    print(total)

# %% [markdown]
# # Passing information to function

# %%
def add_nums(num1, num2):
    total = num1 + num2
    print(total)

# %%
add_nums(23, 34)
# Out:
# 57

# %%
type(num1)
# Out:
# int

# %%
add_nums(num2= 53, num1=14)
# Out:
# 67

# %%
def bio_data(last_name, first_name,age, weight):
    print(last_name)
    print(first_name)
    print(age)
    print(weight)

# %%
bio_data("Qaya", "Abbasi", 35, 54)
# Out:
# Qaya
# Abbasi
# 35
# 54

# %%
def bio_data(last_name, first_name, weight,age):
    print(last_name)
    print(first_name)
    print(age)
    print(weight)

# %%
bio_data("Qaya", "Abbasi", 35, 54)
# Out:
# Qaya
# Abbasi
# 54
# 35

# %%
age = int(input())
# Out:
#  23

# %%
bio_data(first_name="Qaya", last_name="Abbasi", age=age, weight= 54)
# Out:
# Abbasi
# Qaya
# 23
# 54

# %% [markdown]
# # Functions: Passing information to them a different way

# %%
def bio_data_with_defeault(last_name, first_name,age, weight=54):
    print(last_name)
    print(first_name)
    print(age)
    print(weight)

# %%
bio_data(first_name="Anas", last_name="khan", age=age, weight= 60)
# Out:
# khan
# Anas
# 23
# 60

# %% [markdown]
# # Task
# * write a function call registration which take email and pasword from user and save them in any way .
# * write another funtion which take email an password  and check in te saved date, if date is available so your function should print a login successful message if not show  invalid credientials please regiter  first.

# %%
user_info ={}

def registration(email, password):
    email = input("Enter your Email: ")
    password = input("Enter your password:")
    user_info["email"] = email
    user_info["password"] = password

# %%
registration("qayasabbasi98@gmail.com", "123456789")
# Out:
# Enter your Email:  qa
# Enter your password: 12

# %%
user_info
# Out:
# {'email': 'qa', 'password': '12'}

# %%
user_info["email"]
# Out:
# 'qa'

# %%
def login(email, password):
    if email == user_info["email"] and password == user_info["password"]:
        print("login successful.")
    else:
        print("invalid credientials")

# %%
user_info ={}

def registration(email, password):
    email = input("Enter your Email: ")
    password = input("Enter your password:")
    user_info["email"] = email
    user_info["password"] = password

# %%
def bio_data(first_name, last_name, class_name, city, country, age):
    print("First Name:", first_name)
    print("Last Name:", last_name)
    print("Class:", class_name)
    print("City:", city)
    print("Country:", country)
    print("Age:", age)

# function call
bio_data("Qayas", "Abbasi", "CDE", "Karachi", "Pakistan", "35")
# Out:
# First Name: Qayas
# Last Name: Abbasi
# Class: CDE
# City: Karachi
# Country: Pakistan
# Age: 35

# %%
def bio_data(first_name, last_name, coruse, **other_data):
    print("First Name:", first_name)
    print("Last Name:", last_name)
    print("coruse:", course)
    for i in other_data.items():
        print(i)

# %%
def bio_data(first_name, last_name, course, **other_data):
    print("First Name:", first_name)
    print("Last Name:", last_name)
    print("Course:", course)   # yaha course likha hai aur upar bhi same naam
    for key, value in other_data.items():
        print(key.capitalize() + ":", value)

# function call
bio_data("Qayas", "Abbasi", "CDE", city="Karachi", country="Pakistan", age="20")
# Out:
# First Name: Qayas
# Last Name: Abbasi
# Course: CDE
# City: Karachi
# Country: Pakistan
# Age: 20

# %% [markdown]
# # Task
# * write a function call registration which take email and pasword from user and save
# * write another funtion which take email an password and check in te saved date, if date is available so your function should print a login successful message if not show invalid credientials please regiter first.
