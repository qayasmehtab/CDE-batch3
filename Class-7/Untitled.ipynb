# %% [markdown]
# # Creating a list of dictionaries

# %%
names= ["Qayas", "Mehtab"]
bio_data={"first_name": "Qayas", "last_name": "Mehtab", }

# %%
cde_class=[
    {
        "first_name": "Qayas",
        "last_name": "Mehtab",
        "adress": "karachi",
        
    },
 
  {
        "first_name": "Muhammad",
        "last_name": "Noman ",
        "adress": "Lahore",
        
    },
       
    {
        "first_name": "Muhammad",
        "last_name": "Salman",
        "adress": "Islamabad",
        
    },
    
]

# %%
names[0]
# Out:
# 'Qayas'

# %%
cde_class[0]
# Out:
# {'first_name': 'Qayas', 'last_name': 'Mehtab', 'adress': 'karachi'}

# %% [markdown]
# ## Mini Task
#
# - Add another studer in this list
# - print all student first name
# - Add Grade for each student and print all the student with grade A

# %%
cde_class.append({
    "first_name": "Muhammad",
    "last_name": "Naqeeb ",
    "adress": "Islamabad",
        
})
cde_class
# Out:
# [{'first_name': 'Qayas', 'last_name': 'Mehtab', 'adress': 'karachi'},
#  {'first_name': 'Muhammad', 'last_name': 'Noman ', 'adress': 'Lahore'},
#  {'first_name': 'Muhammad', 'last_name': 'Salman', 'adress': 'Islamabad'},
#  {'first_name': 'Muhammad', 'last_name': 'Naqeeb ', 'adress': 'Islamabad'},
#  {'first_name': 'Muhammad', 'last_name': 'Naqeeb ', 'adress': 'Islamabad'},
#  {'first_name': 'Muhammad', 'last_name': 'Naqeeb ', 'adress': 'Islamabad'}]

# %%
bio_data["first_name"]
# Out:
# 'Qayas'

# %%
cde_class[1] ["first_name"]
# Out:
# 'Muhammad'

# %%
for i in names:
    print(i)
# Out:
# Qayas
# Mehtab

# %%
for i in cde_class:
    print(i["last_name"])
# Out:
# Mehtab
# Naqeeb
# Noman
# Salman
# Mehtab

# %%
# duplicate name inter in data then use it.
cde_class = [dict(i) for i in {tuple(d.items()) for d in cde_class}]

# %%
cde_class
# Out:
# [{'first_name': 'Muhammad',
#   'last_name': 'Noman',
#   'adress': 'Lahore',
#   'grade': 'B'},
#  {'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'adress': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'Muhammad',
#   'last_name': 'Naqeeb',
#   'adress': 'Islamabad',
#   'grade': 'D'},
#  {'first_name': 'Ayaz',
#   'last_name': 'Mehtab',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'Muhammad',
#   'last_name': 'Salman',
#   'adress': 'Islamabad',
#   'grade': 'C'}]

# %%
cde_class.append({
     "first_name": "Ayaz",
     "last_name": "Mehtab",
     "adrees": "karachi"
     
    }),
cde_class.append({
     "first_name": "Ayaz",
     "last_name": "Mehtab",
     "adrees": "karachi"
     
    }),
cde_class
# Out:
# [{'first_name': 'Ayaz', 'last_name': 'Mehtab', 'adrees': 'karachi'},
#  {'first_name': 'Muhammad', 'last_name': 'Salman', 'adress': 'Islamabad'},
#  {'first_name': 'Muhammad', 'last_name': 'Noman ', 'adress': 'Lahore'},
#  {'first_name': 'Qayas', 'last_name': 'Mehtab', 'adress': 'karachi'},
#  {'first_name': 'Muhammad', 'last_name': 'Naqeeb ', 'adress': 'Islamabad'},
#  {'first_name': 'Ayaz', 'last_name': 'Mehtab', 'adrees': 'karachi'},
#  {'first_name': 'Ayaz', 'last_name': 'Mehtab', 'adrees': 'karachi'}]

# %%
for i in cde_class:
    print(i["first_name"])
# Out:
# Ayaz
# Muhammad
# Muhammad
# Qayas
# Muhammad
# Ayaz
# Ayaz

# %%
# duplicate name inter in data then use it.
cde_class = [dict(i) for i in {tuple(d.items()) for d in cde_class}]

# %%
for i in cde_class:
    print(i["first_name"])
# Out:
# Qayas
# Muhammad
# Muhammad
# Muhammad
# Ayaz

# %%
cde_class
# Out:
# [{'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'adress': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'Muhammad',
#   'last_name': 'Naqeeb',
#   'adress': 'Islamabad',
#   'grade': 'A'},
#  {'first_name': 'Muhammad',
#   'last_name': 'Noman',
#   'adress': 'Lahore',
#   'grade': 'A'},
#  {'first_name': 'Muhammad',
#   'last_name': 'Salman',
#   'adress': 'Islamabad',
#   'grade': 'C'},
#  {'first_name': 'Ayaz',
#   'last_name': 'Mehtab',
#   'adrees': 'karachi',
#   'grade': 'A'}]

# %%
for i in cde_class:
    if i["first_name"] == "Ayaz":
        i["grade"] = "A"
    elif i["last_name"] == "Salman":
         i["grade"] = "C"
    elif i["last_name"] == "Noman":
        i["grade"] = "B"
    elif i["first_name"] == "Qayas":
         i["grade"]="A"
    elif i["last_name"] == "Naqeeb":
        i["grade"]= "D"

# %%
for i in cde_class:
    i["first_name"] = i["first_name"].strip()
    i["last_name"] = i["last_name"].strip()

# %%
cde_class
# Out:
# [{'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'adress': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'Muhammad',
#   'last_name': 'Naqeeb',
#   'adress': 'Islamabad',
#   'grade': 'D'},
#  {'first_name': 'Muhammad',
#   'last_name': 'Noman',
#   'adress': 'Lahore',
#   'grade': 'B'},
#  {'first_name': 'Muhammad',
#   'last_name': 'Salman',
#   'adress': 'Islamabad',
#   'grade': 'C'},
#  {'first_name': 'Ayaz',
#   'last_name': 'Mehtab',
#   'adrees': 'karachi',
#   'grade': 'A'}]

# %%
for i in cde_class:
    print(i)
# Out:
# {'first_name': 'Qayas', 'last_name': 'Mehtab', 'adress': 'karachi', 'grade': 'A'}
# {'first_name': 'Muhammad', 'last_name': 'Naqeeb', 'adress': 'Islamabad', 'grade': 'D'}
# {'first_name': 'Muhammad', 'last_name': 'Noman', 'adress': 'Lahore', 'grade': 'B'}
# {'first_name': 'Muhammad', 'last_name': 'Salman', 'adress': 'Islamabad', 'grade': 'C'}
# {'first_name': 'Ayaz', 'last_name': 'Mehtab', 'adrees': 'karachi', 'grade': 'A'}

# %%
for i in cde_class:
    if i["grade"] == "A":
        print(i["first_name"], i["grade"])
# Out:
# Qayas A
# Ayaz A

# %% [markdown]
# ## Mini Task
#
# - Add another studer in this list
# - print all student first name
# - Add Grade for each student and print all the student with grade A

# %%
cde_class.append({
    "first_name": "Qayas",
     "last_name": "Mehtab",
     "fatehr_name": "Abbasi",
     "age":"35",
     "adrees": "karachi",
     "grade": "A"
     
    })

cde_class.append({
    "first_name": "anas",
     "last_name": "khan",
     "fatehr_name": "pathen",
     "age":"30",
     "adrees": "lahore",
     "grade": "B"
     
    })

cde_class.append({
      "first_name": "rehan",
     "last_name": "khan",
     "fatehr_name": "pathen",
     "age":"20",
     "adrees": "islamabad",
     "grade": "c"
     
    })

cde_class.append({
      "first_name": "umair",
     "last_name": "nawaz",
     "fatehr_name": "khan",
     "age":"30",
     "adrees": "karachi",
     "grade": "A"
     
    })
cde_class
# Out:
# [{'first_name': 'Ayaz',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'aman',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '30',
#   'adrees': 'karachi',
#   'grade': 'B'},
#  {'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'anas',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '30',
#   'adrees': 'lahore',
#   'grade': 'B'},
#  {'first_name': 'rehan',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '20',
#   'adrees': 'islamabad',
#   'grade': 'c'},
#  {'first_name': 'umair',
#   'last_name': 'nawaz',
#   'fatehr_name': 'khan',
#   'age': '30',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
# ...

# %%
cde_class.append({
    "first_name": "Qasim", 
    "last_name": "khan",
    "fater_name": "ikram",
    "age": 29, 
    "grade": "A"
})
cde_class
# Out:
# [{'first_name': 'Ayaz',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'aman',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '30',
#   'adrees': 'karachi',
#   'grade': 'B'},
#  {'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'anas',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '30',
#   'adrees': 'lahore',
#   'grade': 'B'},
#  {'first_name': 'rehan',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '20',
#   'adrees': 'islamabad',
#   'grade': 'c'},
#  {'first_name': 'umair',
#   'last_name': 'nawaz',
#   'fatehr_name': 'khan',
#   'age': '30',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
# ...

# %%
cde_class.append({
    "first_name": "yasir",
    "last_name": "ahmed",
    "fahter_name": "khalil",
    "age": 43,
    "grade": "C"   
    }),
cde_class
# Out:
# [{'first_name': 'Ayaz',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'aman',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '30',
#   'adrees': 'karachi',
#   'grade': 'B'},
#  {'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'anas',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '30',
#   'adrees': 'lahore',
#   'grade': 'B'},
#  {'first_name': 'rehan',
#   'last_name': 'khan',
#   'fatehr_name': 'pathen',
#   'age': '20',
#   'adrees': 'islamabad',
#   'grade': 'c'},
#  {'first_name': 'umair',
#   'last_name': 'nawaz',
#   'fatehr_name': 'khan',
#   'age': '30',
#   'adrees': 'karachi',
#   'grade': 'A'},
#  {'first_name': 'Qayas',
#   'last_name': 'Mehtab',
#   'fatehr_name': 'Abbasi',
#   'age': '35',
#   'adrees': 'karachi',
#   'grade': 'A'},
# ...

# %%
for i in cde_class:
    print(i)
# Out:
# {'first_name': 'Ayaz', 'last_name': 'Mehtab', 'fatehr_name': 'Abbasi', 'age': '35', 'adrees': 'karachi', 'grade': 'A'}
# {'first_name': 'aman', 'last_name': 'khan', 'fatehr_name': 'pathen', 'age': '30', 'adrees': 'karachi', 'grade': 'B'}
# {'first_name': 'Qayas', 'last_name': 'Mehtab', 'fatehr_name': 'Abbasi', 'age': '35', 'adrees': 'karachi', 'grade': 'A'}
# {'first_name': 'anas', 'last_name': 'khan', 'fatehr_name': 'pathen', 'age': '30', 'adrees': 'lahore', 'grade': 'B'}
# {'first_name': 'rehan', 'last_name': 'khan', 'fatehr_name': 'pathen', 'age': '20', 'adrees': 'islamabad', 'grade': 'c'}
# {'first_name': 'umair', 'last_name': 'nawaz', 'fatehr_name': 'khan', 'age': '30', 'adrees': 'karachi', 'grade': 'A'}
# {'first_name': 'Qayas', 'last_name': 'Mehtab', 'fatehr_name': 'Abbasi', 'age': '35', 'adrees': 'karachi', 'grade': 'A'}
# {'first_name': 'anas', 'last_name': 'khan', 'fatehr_name': 'pathen', 'age': '30', 'adrees': 'lahore', 'grade': 'B'}
# ...

# %%
# duplicate name inter in data then use it.
cde_class = [dict(i) for i in {tuple(d.items()) for d in cde_class}]

# %%
for i in cde_class:
    print(i)
# Out:
# {'first_name': 'umair', 'last_name': 'nawaz', 'fatehr_name': 'khan', 'age': '30', 'adrees': 'karachi', 'grade': 'A'}
# {'first_name': 'anas', 'last_name': 'khan', 'fatehr_name': 'pathen', 'age': '30', 'adrees': 'lahore', 'grade': 'B'}
# {'first_name': 'yasir', 'last_name': 'ahmed', 'fahter_name': 'khalil', 'age': 43, 'grade': 'C'}
# {'first_name': 'Qasim', 'last_name': 'khan', 'fater_name': 'ikram', 'age': 29, 'grade': 'A'}
# {'first_name': 'Ayaz', 'last_name': 'Mehtab', 'fatehr_name': 'Abbasi', 'age': '35', 'adrees': 'karachi', 'grade': 'A'}
# {'first_name': 'rehan', 'last_name': 'khan', 'fatehr_name': 'pathen', 'age': '20', 'adrees': 'islamabad', 'grade': 'c'}
# {'first_name': 'Qayas', 'last_name': 'Mehtab', 'fatehr_name': 'Abbasi', 'age': '35', 'adrees': 'karachi', 'grade': 'A'}
# {'first_name': 'aman', 'last_name': 'khan', 'fatehr_name': 'pathen', 'age': '30', 'adrees': 'karachi', 'grade': 'B'}

# %%
for i in cde_class:
    print(i["first_name"])
# Out:
# umair
# anas
# yasir
# Qasim
# Ayaz
# rehan
# Qayas
# aman

# %%
for i in cde_class:
    print=

# %%
store = { 
    "fruit": ["apple", "mango", "orange"],
    "drinks": ["mango juice", "apple juice", "banana juice"]
}

# %%
store
# Out:
# {'fruit': ['apple', 'mango', 'orange'],
#  'drinks': ['mango juice', 'apple juice', 'banana juice']}

# %%
store["medinicn"]= ["panadol", "disprin"]

# %%
store
# Out:
# {'fruit': ['apple', 'mango', 'orange'],
#  'drinks': ['mango juice', 'apple juice', 'banana juice'],
#  'medinicn': ['panadol', 'disprin']}

# %%
contacts = {
    "Qayas": {"Phone": 32020000,"Email": "qayas@gmail.com"},
    "anas": {"Phone": 31020000,"Email": "anas@gmail.com"}
}

# %%
contacts
# Out:
# {'Qayas': {'Phone': 32020000, 'Email': 'qayas@gmail.com'},
#  'anas': {'Phone': 31020000, 'Email': 'anas@gmail.com'}}

# %%
contacts ["ayaz"] = {"Phone": 31024681, "Email": "ayaz@gmail.com"}

# %%
company = {
    "HR": [
        {"name": "Ali", "salary": 40000, "experience": 5},
        {"name": "Anas", "salary": 30000, "experience": 3}
    ],
    "IT": [
        {"name": "Qayas", "salary": 90000, "experience": 2},
        {"name": "Anas", "salary": 70000, "experience": 1}
    ],
    "Finance": [
        {"name": "rehan", "salary": 100000, "experience": 4},
        {"name": "kashif", "salary": 70000, "experience": 3}
    ]
}

# %%
company
# Out:
# {'HR': [{'name': 'Ali', 'salary': 40000, 'experience': 5},
#   {'name': 'Anas', 'salary': 30000, 'experience': 3}],
#  'IT': [{'name': 'Qayas', 'salary': 90000, 'experience': 2},
#   {'name': 'Anas', 'salary': 70000, 'experience': 1}],
#  'Finance': [{'name': 'rehan', 'salary': 100000, 'experience': 4},
#   {'name': 'kashif', 'salary': 70000, 'experience': 3}]}

# %%
for i in company:
    print(i)
# Out:
# HR
# IT
# Finance

# %%
print(company["IT"])
# Out:
# [{'name': 'Qayas', 'salary': 90000, 'experience': 2}, {'name': 'Anas', 'salary': 70000, 'experience': 1}]

# %%
for i in company:
    print(i)
# Out:
# HR
# IT
# Finance

# %%
company["HR"].append({"name": "Qasim", "salary": 55000, "experience": 1})

# %%
company["HR"]
# Out:
# [{'name': 'Ali', 'salary': 40000, 'experience': 5},
#  {'name': 'Anas', 'salary': 30000, 'experience': 3},
#  {'name': 'Qasim', 'salary': 55000, 'experience': 1}]

# %%
company["HR"][2]["salary"]+10000
# Out:
# 65000

# %%
company["HR"]
# Out:
# [{'name': 'Ali', 'salary': 40000, 'experience': 5},
#  {'name': 'Anas', 'salary': 30000, 'experience': 3},
#  {'name': 'Qasim', 'salary': 55000, 'experience': 1}]

# %%
company["HR"] = [
    {"name": "Ali", "salary": 40000, "experience": 5},
    {"name": "Anas", "salary": 30000, "experience": 3},
    {"name": "Qasim", "salary": 55000, "experience": 2}
]

# %%
company["HR"][2]["salary"] += 10000

# %%
print(company["HR"][2])
# Out:
# {'name': 'Qasim', 'salary': 65000, 'experience': 2}

# %%
for i in company:
    for j in company [i]:
        if j["experience"] > 3:
            print(j)
# Out:
# {'name': 'Ali', 'salary': 40000, 'experience': 5}
# {'name': 'rehan', 'salary': 100000, 'experience': 4}
